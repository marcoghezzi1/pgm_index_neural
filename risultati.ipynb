# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_con_dati = pd.read_csv('results.csv')
results_con_dati[-1:]
# Out:
#                                    dataset  err medio iniziale  \
# 8  datipisa/segments_wiki_ts_1M_uint64.csv           29.357498
#
#                   loss optimizer       lr  batch size  epochs  \
# 8  mean_absolute_error      Adam  0.00001         100    2000
#
#    err medio finale  errore massimo
# 8         25.681251      175.164593

# %%
img = plt.imread('./logs/plot/20201216-142326.eps')
img = plt.imshow(img)

# %%
results_ = pd.read_csv('results_training.csv')
results_[-1:]
# Out:
#                                    dataset  err medio iniziale  \
# 5  datipisa/segments_wiki_ts_1M_uint64.csv           29.357498
#
#                   loss optimizer       lr  batch size  epochs  \
# 5  mean_absolute_error      Adam  0.00001         100    1000
#
#    err medio finale  errore massimo
# 5     233431.670168   998696.519002

# %%
img = plt.imread('./logs/plot/20201217-040650.eps')
img = plt.imshow(img)
